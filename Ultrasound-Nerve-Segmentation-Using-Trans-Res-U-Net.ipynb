# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2
from tqdm import tqdm
from glob import glob
from PIL import Image
from skimage.transform import resize
from sklearn.model_selection import train_test_split, KFold

import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

K.set_image_data_format('channels_last')

# %% [markdown]
# ## Building the training dataset.

# %%
path = "../input/ultrasound-nerve-segmentation/train/"
file_list = os.listdir(path)
file_list[:20]
# Out:
# ['29_21.tif',
#  '15_7_mask.tif',
#  '40_106_mask.tif',
#  '34_117_mask.tif',
#  '11_25.tif',
#  '21_25_mask.tif',
#  '1_72_mask.tif',
#  '45_90.tif',
#  '43_32.tif',
#  '46_68.tif',
#  '8_101.tif',
#  '37_107.tif',
#  '25_28_mask.tif',
#  '8_29.tif',
#  '24_11_mask.tif',
#  '7_33_mask.tif',
#  '44_68.tif',
#  '46_96.tif',
#  '44_46_mask.tif',
#  '7_97.tif']

# %% [markdown]
# **Sort the file list in ascending order and seperate it into images and masks**<br/>

# %%
train_image = []
train_mask = glob(path + '*_mask*')

for i in train_mask:
    train_image.append(i.replace('_mask', ''))
        
print(train_image[:10],"\n" ,train_mask[:10])
# Out:
# ['../input/ultrasound-nerve-segmentation/train/15_7.tif', '../input/ultrasound-nerve-segmentation/train/40_106.tif', '../input/ultrasound-nerve-segmentation/train/34_117.tif', '../input/ultrasound-nerve-segmentation/train/21_25.tif', '../input/ultrasound-nerve-segmentation/train/1_72.tif', '../input/ultrasound-nerve-segmentation/train/25_28.tif', '../input/ultrasound-nerve-segmentation/train/24_11.tif', '../input/ultrasound-nerve-segmentation/train/7_33.tif', '../input/ultrasound-nerve-segmentation/train/44_46.tif', '../input/ultrasound-nerve-segmentation/train/16_19.tif']
#  ['../input/ultrasound-nerve-segmentation/train/15_7_mask.tif', '../input/ultrasound-nerve-segmentation/train/40_106_mask.tif', '../input/ultrasound-nerve-segmentation/train/34_117_mask.tif', '../input/ultrasound-nerve-segmentation/train/21_25_mask.tif', '../input/ultrasound-nerve-segmentation/train/1_72_mask.tif', '../input/ultrasound-nerve-segmentation/train/25_28_mask.tif', '../input/ultrasound-nerve-segmentation/train/24_11_mask.tif', '../input/ultrasound-nerve-segmentation/train/7_33_mask.tif', '../input/ultrasound-nerve-segmentation/train/44_46_mask.tif', '../input/ultrasound-nerve-segmentation/train/16_19_mask.tif']

# %%
# Display the first image and mask of the first subject.
image1 = np.array(Image.open(path+"1_1.tif"))
image1_mask = np.array(Image.open(path+"1_1_mask.tif"))
image1_mask = np.ma.masked_where(image1_mask == 0, image1_mask)

fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(image1, cmap = 'gray')

ax[1].imshow(image1_mask, cmap = 'gray')

ax[2].imshow(image1, cmap = 'gray', interpolation = 'none')
ax[2].imshow(image1_mask, cmap = 'jet', interpolation = 'none', alpha = 0.7)

# %% [markdown]
# Now, I try to load all image files and store them variables X and y.<br/>

# %% [markdown]
# ## How to deal with train_masks.csv ?

# %%
width = 128
height = 128

# %% [markdown]
# Let's modularize this work.

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import Input
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate,add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
def dice_coef(y_true, y_pred):
    smooth = 0.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def jacard(y_true, y_pred):

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum ( y_true_f * y_pred_f)
    union = K.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)

    return intersection/union


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import *

def res_block(inputs,filter_size):
  
    # First Conv2D layer
    cb1 = Conv2D(filter_size,(3,3),padding = 'same',activation="relu")(inputs)
    # Second Conv2D layer parallel to the first one
    cb2 = Conv2D(filter_size,(1,1),padding = 'same',activation="relu")(inputs)
    # Addition of cb1 and cb2
    add = Add()([cb1,cb2])
    
    return add

def res_path(inputs,filter_size,path_number):
  
    # Minimum one residual block for every res path
    skip_connection = res_block(inputs, filter_size)
    
    # Two serial residual blocks for res path 2
    if path_number == 2:
        skip_connection = res_block(skip_connection,filter_size)
    
    # Three serial residual blocks for res path 1
    elif path_number == 1:
        skip_connection = res_block(skip_connection,filter_size)
        skip_connection = res_block(skip_connection,filter_size)
    
    return skip_connection

def decoder_block(inputs, mid_channels, out_channels):
    
    conv_kwargs = dict(
        activation='relu',
        padding='same',
        kernel_initializer='he_normal',
        data_format='channels_last'  
    )
    
    # Upsampling (nearest neighbor interpolation) layer
    db = UpSampling2D(size=(2, 2))(inputs)
    # First conv2D layer 
    db = Conv2D(mid_channels, 3, **conv_kwargs)(db)
    # Second conv2D layer
    db = Conv2D(out_channels, 3, **conv_kwargs)(db)

    return db

def TransResUNet(input_size=(512, 512, 1)):
    
    # Input 
    inputs = Input(input_size)
    inp = inputs
    input_shape = input_size
    
    # Handling input channels 
    # input with 1 channel will be converted to 3 channels to be compatible with VGG16 pretrained encoder 
    if input_size[-1] < 3:
        inp = Conv2D(3, 1)(inputs)                         
        input_shape = (input_size[0], input_size[0], 3)  
    else:
        inp = inputs
        input_shape = input_size

    # VGG16 with imagenet weights
    encoder = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
       
    # First encoder block
    enc1 = encoder.get_layer(name='block1_conv1')(inp)
    enc1 = encoder.get_layer(name='block1_conv2')(enc1)
    # Second encoder block
    enc2 = MaxPooling2D(pool_size=(2, 2))(enc1)
    enc2 = encoder.get_layer(name='block2_conv1')(enc2)
    enc2 = encoder.get_layer(name='block2_conv2')(enc2)
    # Third encoder block
    enc3 = MaxPooling2D(pool_size=(2, 2))(enc2)
    enc3 = encoder.get_layer(name='block3_conv1')(enc3)
    enc3 = encoder.get_layer(name='block3_conv2')(enc3)
    enc3 = encoder.get_layer(name='block3_conv3')(enc3)

    # Center block
    center = MaxPooling2D(pool_size=(2, 2))(enc3)
    center = decoder_block(center, 512, 256)

    # Decoder block corresponding to third encoder
    res_path3 = res_path(enc3,128,3)
    dec3 = concatenate([res_path3, center], axis=3)
    dec3 = decoder_block(dec3, 256, 64)
    # Decoder block corresponding to second encoder
    res_path2 = res_path(enc2,64,2)
    dec2 = concatenate([res_path2, dec3], axis=3)
    dec2 = decoder_block(dec2, 128, 64)
    # Final Block concatenation with first encoded feature 
    res_path1 = res_path(enc1,32,1)
    dec1 = concatenate([res_path1, dec2], axis=3)
    dec1 = Conv2D(32, 3, padding='same', kernel_initializer='he_normal')(dec1)
    dec1 = ReLU()(dec1)

    # Output
    out = Conv2D(1, 1)(dec1)
    out = Activation('sigmoid')(out)  
    
    # Final model
    model = Model(inputs=[inputs], outputs=[out])
    
    return model

# %%
def train_generator(data_frame, batch_size, train_path, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
  
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        directory = train_path,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        directory = train_path,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
pos_mask = []
pos_img = []
neg_mask = []
neg_img = []

for mask_path, img_path in zip(train_mask, train_image):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if np.sum(mask) == 0:
        neg_mask.append(mask_path)
        neg_img.append(img_path)
    else:
        pos_mask.append(mask_path)
        pos_img.append(img_path)

# %%
# !mkdir generated
# !mkdir generated/img

# %%
def flip_up_down(img):
    newImg = img.copy()
    return cv2.flip(newImg, 0)

def flip_right_left(img):
    newImg = img.copy()
    return cv2.flip(newImg, 1)

# %%
gen_img = []
gen_mask = []

for (img_path, mask_path) in tqdm(zip(pos_img, pos_mask)):
    image_name = img_path.split('/')[-1].split('.')[0]

    uf_img_path = 'generated/img/'+image_name+'_uf.jpg'
    uf_mask_path = 'generated/img/'+image_name+'_uf_mask.jpg'
    rf_img_path = 'generated/img/'+image_name+'_rf.jpg'
    rf_mask_path = 'generated/img/'+image_name+'_rf_mask.jpg'

    img = cv2.imread(img_path)
    mask = cv2.imread(mask_path)

    uf_img = flip_up_down(img)
    uf_mask = flip_up_down(mask)
    rf_img = flip_right_left(img)
    rf_mask = flip_right_left(mask)

    cv2.imwrite(uf_img_path, uf_img)
    cv2.imwrite(uf_mask_path, uf_mask)
    cv2.imwrite(rf_img_path, rf_img)
    cv2.imwrite(rf_mask_path, rf_mask)
    
    gen_img.append(uf_img_path)
    gen_mask.append(uf_mask_path)
    gen_img.append(rf_img_path)
    gen_mask.append(rf_mask_path)
# Out:
# 2323it [00:51, 44.76it/s]

# %%
aug_img = gen_img + train_image
aug_mask = gen_mask + train_mask

df_ = pd.DataFrame(data={"filename": aug_img, 'mask' : aug_mask})
df = df_.sample(frac=1).reset_index(drop=True)

kf = KFold(n_splits = 5, shuffle=False)

# %%
histories = []
losses = []
accuracies = []
dicecoefs = []
jacards = []

train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

EPOCHS = 40
BATCH_SIZE = 32

for k, (train_index, test_index) in enumerate(kf.split(df)):
    train_data_frame = df.iloc[train_index]
    test_data_frame = df.iloc[test_index]
    
    train_gen = train_generator(train_data_frame, BATCH_SIZE,
                                None,
                                train_generator_args,
                                target_size=(height, width))

    test_gener = train_generator(test_data_frame, BATCH_SIZE,
                                None,
                                dict(),
                                target_size=(height, width))

    model = TransResUNet(input_size=(height,width, 1))
    model.compile(optimizer=Adam(lr=2e-5), loss=dice_coef_loss, \
                      metrics=[jacard, dice_coef, 'binary_accuracy'])

    model_checkpoint = ModelCheckpoint(str(k+1) + '_unet_ner_seg.hdf5', 
                                       verbose=1, 
                                       save_best_only=True)

    history = model.fit(train_gen,
                                  steps_per_epoch=len(train_data_frame) // BATCH_SIZE, 
                                  epochs=EPOCHS, 
                                  callbacks=[model_checkpoint],
                                  validation_data = test_gener,
                                  validation_steps=len(test_data_frame) // BATCH_SIZE)
    
    model = load_model(str(k+1) + '_unet_ner_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'jacard': jacard, 'dice_coef': dice_coef})
    
    test_gen = train_generator(test_data_frame, BATCH_SIZE,
                                None,
                                dict(),
                                target_size=(height, width))
    results = model.evaluate(test_gen, steps=len(test_data_frame) // BATCH_SIZE)
    results = dict(zip(model.metrics_names,results))
    
    histories.append(history)
    accuracies.append(results['binary_accuracy'])
    losses.append(results['loss'])
    dicecoefs.append(results['dice_coef'])
    jacards.append(results['jacard'])
    
    break
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Found 8224 images.
# Found 8224 images.
# Epoch 1/40
# 256/257 [============================>.] - ETA: 0s - loss: -0.4614 - jacard: 0.3084 - dice_coef: 0.4614 - binary_accuracy: 0.9512Found 2057 images.
# Found 2057 images.
# 64/64 [==============================] - 21s 332ms/step - loss: -0.5741 - jacard: 0.4039 - dice_coef: 0.5741 - binary_accuracy: 0.9821
#
# Epoch 00001: val_loss improved from inf to -0.57407, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 159s 619ms/step - loss: -0.4619 - jacard: 0.3088 - dice_coef: 0.4619 - binary_accuracy: 0.9513 - val_loss: -0.5741 - val_jacard: 0.4039 - val_dice_coef: 0.5741 - val_binary_accuracy: 0.9821
# Epoch 2/40
# 64/64 [==============================] - 20s 307ms/step - loss: -0.6199 - jacard: 0.4505 - dice_coef: 0.6199 - binary_accuracy: 0.9839
#
# Epoch 00002: val_loss improved from -0.57407 to -0.61990, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 562ms/step - loss: -0.5794 - jacard: 0.4120 - dice_coef: 0.5794 - binary_accuracy: 0.9832 - val_loss: -0.6199 - val_jacard: 0.4505 - val_dice_coef: 0.6199 - val_binary_accuracy: 0.9839
# Epoch 3/40
# 64/64 [==============================] - 19s 304ms/step - loss: -0.6340 - jacard: 0.4661 - dice_coef: 0.6340 - binary_accuracy: 0.9870
#
# Epoch 00003: val_loss improved from -0.61990 to -0.63398, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 558ms/step - loss: -0.6102 - jacard: 0.4442 - dice_coef: 0.6102 - binary_accuracy: 0.9842 - val_loss: -0.6340 - val_jacard: 0.4661 - val_dice_coef: 0.6340 - val_binary_accuracy: 0.9870
# Epoch 4/40
# 64/64 [==============================] - 20s 312ms/step - loss: -0.6558 - jacard: 0.4900 - dice_coef: 0.6558 - binary_accuracy: 0.9867
#
# Epoch 00004: val_loss improved from -0.63398 to -0.65582, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 563ms/step - loss: -0.6299 - jacard: 0.4648 - dice_coef: 0.6299 - binary_accuracy: 0.9853 - val_loss: -0.6558 - val_jacard: 0.4900 - val_dice_coef: 0.6558 - val_binary_accuracy: 0.9867
# Epoch 5/40
# 64/64 [==============================] - 19s 304ms/step - loss: -0.6656 - jacard: 0.5011 - dice_coef: 0.6656 - binary_accuracy: 0.9874
#
# Epoch 00005: val_loss improved from -0.65582 to -0.66565, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 560ms/step - loss: -0.6456 - jacard: 0.4820 - dice_coef: 0.6456 - binary_accuracy: 0.9858 - val_loss: -0.6656 - val_jacard: 0.5011 - val_dice_coef: 0.6656 - val_binary_accuracy: 0.9874
# Epoch 6/40
# 64/64 [==============================] - 20s 311ms/step - loss: -0.6805 - jacard: 0.5176 - dice_coef: 0.6805 - binary_accuracy: 0.9877
#
# Epoch 00006: val_loss improved from -0.66565 to -0.68050, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 148s 576ms/step - loss: -0.6564 - jacard: 0.4942 - dice_coef: 0.6564 - binary_accuracy: 0.9864 - val_loss: -0.6805 - val_jacard: 0.5176 - val_dice_coef: 0.6805 - val_binary_accuracy: 0.9877
# Epoch 7/40
# 64/64 [==============================] - 20s 306ms/step - loss: -0.6790 - jacard: 0.5160 - dice_coef: 0.6790 - binary_accuracy: 0.9865
#
# Epoch 00007: val_loss did not improve from -0.68050
# 257/257 [==============================] - 144s 559ms/step - loss: -0.6661 - jacard: 0.5045 - dice_coef: 0.6661 - binary_accuracy: 0.9868 - val_loss: -0.6790 - val_jacard: 0.5160 - val_dice_coef: 0.6790 - val_binary_accuracy: 0.9865
# Epoch 8/40
# 64/64 [==============================] - 19s 297ms/step - loss: -0.6870 - jacard: 0.5252 - dice_coef: 0.6870 - binary_accuracy: 0.9885
#
# Epoch 00008: val_loss improved from -0.68050 to -0.68699, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 560ms/step - loss: -0.6734 - jacard: 0.5133 - dice_coef: 0.6734 - binary_accuracy: 0.9870 - val_loss: -0.6870 - val_jacard: 0.5252 - val_dice_coef: 0.6870 - val_binary_accuracy: 0.9885
# Epoch 9/40
# 64/64 [==============================] - 20s 314ms/step - loss: -0.6912 - jacard: 0.5291 - dice_coef: 0.6912 - binary_accuracy: 0.9869
#
# Epoch 00009: val_loss improved from -0.68699 to -0.69117, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 147s 571ms/step - loss: -0.6718 - jacard: 0.5121 - dice_coef: 0.6718 - binary_accuracy: 0.9871 - val_loss: -0.6912 - val_jacard: 0.5291 - val_dice_coef: 0.6912 - val_binary_accuracy: 0.9869
# Epoch 10/40
# 64/64 [==============================] - 19s 301ms/step - loss: -0.6905 - jacard: 0.5298 - dice_coef: 0.6905 - binary_accuracy: 0.9886
#
# Epoch 00010: val_loss did not improve from -0.69117
# 257/257 [==============================] - 144s 560ms/step - loss: -0.6820 - jacard: 0.5242 - dice_coef: 0.6820 - binary_accuracy: 0.9873 - val_loss: -0.6905 - val_jacard: 0.5298 - val_dice_coef: 0.6905 - val_binary_accuracy: 0.9886
# Epoch 11/40
# 64/64 [==============================] - 20s 309ms/step - loss: -0.7029 - jacard: 0.5435 - dice_coef: 0.7029 - binary_accuracy: 0.9888
#
# Epoch 00011: val_loss improved from -0.69117 to -0.70291, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 564ms/step - loss: -0.6852 - jacard: 0.5288 - dice_coef: 0.6852 - binary_accuracy: 0.9875 - val_loss: -0.7029 - val_jacard: 0.5435 - val_dice_coef: 0.7029 - val_binary_accuracy: 0.9888
# Epoch 12/40
# 64/64 [==============================] - 20s 306ms/step - loss: -0.7065 - jacard: 0.5487 - dice_coef: 0.7065 - binary_accuracy: 0.9888
#
# Epoch 00012: val_loss improved from -0.70291 to -0.70646, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 563ms/step - loss: -0.6959 - jacard: 0.5409 - dice_coef: 0.6959 - binary_accuracy: 0.9880 - val_loss: -0.7065 - val_jacard: 0.5487 - val_dice_coef: 0.7065 - val_binary_accuracy: 0.9888
# Epoch 13/40
# 64/64 [==============================] - 19s 298ms/step - loss: -0.7034 - jacard: 0.5451 - dice_coef: 0.7034 - binary_accuracy: 0.9892
#
# Epoch 00013: val_loss did not improve from -0.70646
# 257/257 [==============================] - 143s 558ms/step - loss: -0.6979 - jacard: 0.5428 - dice_coef: 0.6979 - binary_accuracy: 0.9881 - val_loss: -0.7034 - val_jacard: 0.5451 - val_dice_coef: 0.7034 - val_binary_accuracy: 0.9892
# Epoch 14/40
# 64/64 [==============================] - 21s 322ms/step - loss: -0.6848 - jacard: 0.5228 - dice_coef: 0.6848 - binary_accuracy: 0.9857
#
# Epoch 00014: val_loss did not improve from -0.70646
# 257/257 [==============================] - 145s 566ms/step - loss: -0.7015 - jacard: 0.5469 - dice_coef: 0.7015 - binary_accuracy: 0.9882 - val_loss: -0.6848 - val_jacard: 0.5228 - val_dice_coef: 0.6848 - val_binary_accuracy: 0.9857
# Epoch 15/40
# 64/64 [==============================] - 19s 297ms/step - loss: -0.7187 - jacard: 0.5626 - dice_coef: 0.7187 - binary_accuracy: 0.9893
#
# Epoch 00015: val_loss improved from -0.70646 to -0.71865, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 561ms/step - loss: -0.7025 - jacard: 0.5485 - dice_coef: 0.7025 - binary_accuracy: 0.9881 - val_loss: -0.7187 - val_jacard: 0.5626 - val_dice_coef: 0.7187 - val_binary_accuracy: 0.9893
# Epoch 16/40
# 64/64 [==============================] - 20s 311ms/step - loss: -0.7200 - jacard: 0.5645 - dice_coef: 0.7200 - binary_accuracy: 0.9885
#
# Epoch 00016: val_loss improved from -0.71865 to -0.72005, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 565ms/step - loss: -0.7082 - jacard: 0.5549 - dice_coef: 0.7082 - binary_accuracy: 0.9884 - val_loss: -0.7200 - val_jacard: 0.5645 - val_dice_coef: 0.7200 - val_binary_accuracy: 0.9885
# Epoch 17/40
# 64/64 [==============================] - 19s 298ms/step - loss: -0.7225 - jacard: 0.5673 - dice_coef: 0.7225 - binary_accuracy: 0.9891
#
# Epoch 00017: val_loss improved from -0.72005 to -0.72254, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 559ms/step - loss: -0.7129 - jacard: 0.5608 - dice_coef: 0.7129 - binary_accuracy: 0.9886 - val_loss: -0.7225 - val_jacard: 0.5673 - val_dice_coef: 0.7225 - val_binary_accuracy: 0.9891
# Epoch 18/40
# 64/64 [==============================] - 19s 295ms/step - loss: -0.7232 - jacard: 0.5677 - dice_coef: 0.7232 - binary_accuracy: 0.9892
#
# Epoch 00018: val_loss improved from -0.72254 to -0.72322, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 143s 557ms/step - loss: -0.7154 - jacard: 0.5637 - dice_coef: 0.7154 - binary_accuracy: 0.9888 - val_loss: -0.7232 - val_jacard: 0.5677 - val_dice_coef: 0.7232 - val_binary_accuracy: 0.9892
# Epoch 19/40
# 64/64 [==============================] - 20s 312ms/step - loss: -0.7247 - jacard: 0.5697 - dice_coef: 0.7247 - binary_accuracy: 0.9887
#
# Epoch 00019: val_loss improved from -0.72322 to -0.72465, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 145s 563ms/step - loss: -0.7173 - jacard: 0.5662 - dice_coef: 0.7173 - binary_accuracy: 0.9887 - val_loss: -0.7247 - val_jacard: 0.5697 - val_dice_coef: 0.7247 - val_binary_accuracy: 0.9887
# Epoch 20/40
# 64/64 [==============================] - 19s 300ms/step - loss: -0.7258 - jacard: 0.5711 - dice_coef: 0.7258 - binary_accuracy: 0.9895
#
# Epoch 00020: val_loss improved from -0.72465 to -0.72576, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 143s 556ms/step - loss: -0.7196 - jacard: 0.5690 - dice_coef: 0.7196 - binary_accuracy: 0.9889 - val_loss: -0.7258 - val_jacard: 0.5711 - val_dice_coef: 0.7258 - val_binary_accuracy: 0.9895
# Epoch 21/40
# 64/64 [==============================] - 20s 312ms/step - loss: -0.7257 - jacard: 0.5713 - dice_coef: 0.7257 - binary_accuracy: 0.9897
#
# Epoch 00021: val_loss did not improve from -0.72576
# 257/257 [==============================] - 142s 553ms/step - loss: -0.7243 - jacard: 0.5748 - dice_coef: 0.7243 - binary_accuracy: 0.9890 - val_loss: -0.7257 - val_jacard: 0.5713 - val_dice_coef: 0.7257 - val_binary_accuracy: 0.9897
# Epoch 22/40
# 64/64 [==============================] - 19s 300ms/step - loss: -0.7304 - jacard: 0.5770 - dice_coef: 0.7304 - binary_accuracy: 0.9888
#
# Epoch 00022: val_loss improved from -0.72576 to -0.73041, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 560ms/step - loss: -0.7235 - jacard: 0.5736 - dice_coef: 0.7235 - binary_accuracy: 0.9890 - val_loss: -0.7304 - val_jacard: 0.5770 - val_dice_coef: 0.7304 - val_binary_accuracy: 0.9888
# Epoch 23/40
# 64/64 [==============================] - 19s 291ms/step - loss: -0.7267 - jacard: 0.5723 - dice_coef: 0.7267 - binary_accuracy: 0.9885
#
# Epoch 00023: val_loss did not improve from -0.73041
# 257/257 [==============================] - 143s 557ms/step - loss: -0.7293 - jacard: 0.5814 - dice_coef: 0.7293 - binary_accuracy: 0.9891 - val_loss: -0.7267 - val_jacard: 0.5723 - val_dice_coef: 0.7267 - val_binary_accuracy: 0.9885
# Epoch 24/40
# 64/64 [==============================] - 20s 317ms/step - loss: -0.7264 - jacard: 0.5716 - dice_coef: 0.7264 - binary_accuracy: 0.9887
#
# Epoch 00024: val_loss did not improve from -0.73041
# 257/257 [==============================] - 143s 557ms/step - loss: -0.7326 - jacard: 0.5847 - dice_coef: 0.7326 - binary_accuracy: 0.9893 - val_loss: -0.7264 - val_jacard: 0.5716 - val_dice_coef: 0.7264 - val_binary_accuracy: 0.9887
# Epoch 25/40
# 64/64 [==============================] - 19s 301ms/step - loss: -0.6977 - jacard: 0.5377 - dice_coef: 0.6977 - binary_accuracy: 0.9897
#
# Epoch 00025: val_loss did not improve from -0.73041
# 257/257 [==============================] - 143s 555ms/step - loss: -0.7322 - jacard: 0.5841 - dice_coef: 0.7322 - binary_accuracy: 0.9893 - val_loss: -0.6977 - val_jacard: 0.5377 - val_dice_coef: 0.6977 - val_binary_accuracy: 0.9897
# Epoch 26/40
# 64/64 [==============================] - 20s 306ms/step - loss: -0.7233 - jacard: 0.5679 - dice_coef: 0.7233 - binary_accuracy: 0.9880
#
# Epoch 00026: val_loss did not improve from -0.73041
# 257/257 [==============================] - 143s 556ms/step - loss: -0.7290 - jacard: 0.5820 - dice_coef: 0.7290 - binary_accuracy: 0.9891 - val_loss: -0.7233 - val_jacard: 0.5679 - val_dice_coef: 0.7233 - val_binary_accuracy: 0.9880
# Epoch 27/40
# 64/64 [==============================] - 20s 312ms/step - loss: -0.7120 - jacard: 0.5549 - dice_coef: 0.7120 - binary_accuracy: 0.9898
#
# Epoch 00027: val_loss did not improve from -0.73041
# 257/257 [==============================] - 144s 559ms/step - loss: -0.7352 - jacard: 0.5881 - dice_coef: 0.7352 - binary_accuracy: 0.9894 - val_loss: -0.7120 - val_jacard: 0.5549 - val_dice_coef: 0.7120 - val_binary_accuracy: 0.9898
# Epoch 28/40
# 64/64 [==============================] - 19s 299ms/step - loss: -0.7376 - jacard: 0.5859 - dice_coef: 0.7376 - binary_accuracy: 0.9901
#
# Epoch 00028: val_loss improved from -0.73041 to -0.73763, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 144s 560ms/step - loss: -0.7336 - jacard: 0.5862 - dice_coef: 0.7336 - binary_accuracy: 0.9894 - val_loss: -0.7376 - val_jacard: 0.5859 - val_dice_coef: 0.7376 - val_binary_accuracy: 0.9901
# Epoch 29/40
# 64/64 [==============================] - 20s 312ms/step - loss: -0.7346 - jacard: 0.5821 - dice_coef: 0.7346 - binary_accuracy: 0.9899
#
# Epoch 00029: val_loss did not improve from -0.73763
# 257/257 [==============================] - 143s 558ms/step - loss: -0.7422 - jacard: 0.5970 - dice_coef: 0.7422 - binary_accuracy: 0.9897 - val_loss: -0.7346 - val_jacard: 0.5821 - val_dice_coef: 0.7346 - val_binary_accuracy: 0.9899
# Epoch 30/40
# 64/64 [==============================] - 19s 298ms/step - loss: -0.7382 - jacard: 0.5866 - dice_coef: 0.7382 - binary_accuracy: 0.9899
#
# Epoch 00030: val_loss improved from -0.73763 to -0.73821, saving model to 1_unet_ner_seg.hdf5
# 257/257 [==============================] - 143s 556ms/step - loss: -0.7423 - jacard: 0.5984 - dice_coef: 0.7423 - binary_accuracy: 0.9897 - val_loss: -0.7382 - val_jacard: 0.5866 - val_dice_coef: 0.7382 - val_binary_accuracy: 0.9899
# Epoch 31/40
# 64/64 [==============================] - 19s 300ms/step - loss: -0.7294 - jacard: 0.5753 - dice_coef: 0.7294 - binary_accuracy: 0.9884
#
# Epoch 00031: val_loss did not improve from -0.73821
# 257/257 [==============================] - 143s 556ms/step - loss: -0.7430 - jacard: 0.5977 - dice_coef: 0.7430 - binary_accuracy: 0.9898 - val_loss: -0.7294 - val_jacard: 0.5753 - val_dice_coef: 0.7294 - val_binary_accuracy: 0.9884
# Epoch 32/40
# 64/64 [==============================] - 20s 313ms/step - loss: -0.7343 - jacard: 0.5815 - dice_coef: 0.7343 - binary_accuracy: 0.9891
#
# Epoch 00032: val_loss did not improve from -0.73821
# 257/257 [==============================] - 145s 563ms/step - loss: -0.7460 - jacard: 0.6021 - dice_coef: 0.7460 - binary_accuracy: 0.9898 - val_loss: -0.7343 - val_jacard: 0.5815 - val_dice_coef: 0.7343 - val_binary_accuracy: 0.9891
# Epoch 33/40
# 157/257 [=================>............] - ETA: 47s - loss: -0.7386 - jacard: 0.5956 - dice_coef: 0.7386 - binary_accuracy: 0.9896

# %%
import pickle

for h, history in enumerate(histories):

    keys = history.history.keys()
    fig, axs = plt.subplots(1, len(keys)//2, figsize = (25, 5))
    fig.suptitle('No. ' + str(h+1) + ' Fold Results', fontsize=30)

    for k, key in enumerate(list(keys)[:len(keys)//2]):
        training = history.history[key]
        validation = history.history['val_' + key]

        epoch_count = range(1, len(training) + 1)

        axs[k].plot(epoch_count, training, 'r--')
        axs[k].plot(epoch_count, validation, 'b-')
        axs[k].legend(['Training ' + key, 'Validation ' + key])
        
    with open(str(h+1) + '_trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# %%
print('average accuracy : ', np.mean(np.array(accuracies)), '+-', np.std(np.array(accuracies)))
print('average loss : ', np.mean(np.array(losses)), '+-', np.std(np.array(losses)))
print('average jacard : ', np.mean(np.array(jacards)), '+-', np.std(np.array(jacards)))
print('average dice_coe : ', np.mean(np.array(dicecoefs)), '+-', np.std(np.array(dicecoefs)))
# Out:
# average accuracy :  0.9900445 +- 0.0
# average loss :  -0.747118154540658 +- 0.0
# average jacard :  0.59770525 +- 0.0
# average dice_coe :  0.7471182 +- 0.0

# %%
model = load_model('1_unet_ner_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'jacard': jacard, 'dice_coef': dice_coef})

# %%
for i in range(20):
    index=np.random.randint(0,len(test_data_frame.index))
    print(i+1, index)
    img = cv2.imread(test_data_frame['filename'].iloc[index], cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (height, width))
    img = img[np.newaxis, :, :, np.newaxis]
    img = img / 255
    pred = model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.resize(cv2.imread(test_data_frame['mask'].iloc[index]), (height, width))))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# 1 15
# 2 1822
# 3 286
# 4 1953
# 5 1821
# 6 894
# 7 475
# 8 1659
# 9 883
# 10 1377
# 11 71
# 12 1271
# 13 194
# 14 1845
# 15 1576
# 16 1403
# 17 914
# 18 340
# 19 962
# 20 1965
